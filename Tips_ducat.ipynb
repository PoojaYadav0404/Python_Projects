# %%
#can we chnage lines as per our choice, star line, doted line, bold lines, 
#timeframes line little curve line?
#box plot error

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#matplotlib.pylot- to visualise

tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#other dataset of seaborn - tips, iris, titanic, diamonds

# %%
#line plot

x = np.linspace(0,20, 100)
y = np.exp(x)
print(x)
print("value of y" , y)
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
# ...

# %%
plt.plot(x, y)
plt.show()

# %%
np.linspace(1, 10, 4)
# Out:
# array([ 1.,  4.,  7., 10.])

# %%
x = np.linspace(0, 20, 100)
y = np.exp(x)
plt.plot(x, y, "r")
plt.show()

# %%
x = np.linspace(0, 20, 100)
y_sqrt = np.sqrt(x)
y_sqr = np.square(x)
plt.plot(x, y_sqrt, "r", x, y_sqr, "g")
plt.show()

# %%
#scatter plot

x = tips["total_bill"]
y = tips["tip"]
plt.figure(figsize=(10, 5))
plt.scatter(x, y, s = np.array(y)**2, color = "g")
plt.ylabel("Tips")
plt.xlabel("Total Bill")
plt.show()

# %%
#box plot

plt.boxplot(x = "total_bill", data=tips)
plt.show()

# %%
sns.boxplot( x = "day", y = "tip", data = tips)
plt.show()

# %%
tips["smoker"].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
#bar plot

tips["smoker"].value_counts().plot(kind = "bar")
plt.show()

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
#pieplot

tips["day"].value_counts().plot(kind = "pie", autopct = "%.1f%%", labels = ['Sun', 'Sat', 'Thur', 'Fri'], explode = [0.1,0, 0,0])
plt.show()

# %%
#histogram

plt.hist("tip", data = tips, bins=5)
plt.ylabel('tips')
plt.show()

# %%
#same argumentation(x, y, data)- swarmplot, box plot, violin plot, stripplot, regplot

# %%
#swarm plot

sns.swarmplot(x= "smoker", y = "tip", data = tips, hue="sex")
plt.show()

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue= "sex")
plt.show()

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue= "sex", split= True)
plt.show()

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips)
plt.show()

# %%
tips["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.countplot(x = "day", data = tips, hue = "time")
plt.show()

# %%
sns.distplot(tips["total_bill"])
plt.show()
# Out:
# C:\Users\dmm\AppData\Local\Temp\ipykernel_1720\2151783834.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])

# %%
sns.regplot(x = "total_bill", y = "tip", data = tips)
plt.show()

# %%
num_col = tips.select_dtypes(include = np.number).columns
num_col
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')
